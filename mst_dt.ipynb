# %%
import pandas as pd
pd.options.mode.chained_assignment = None

import os

# %%
df_list = []
files = os.listdir(os.getcwd())
files_csv = [f for f in files if f[:5] == 'olist']

for i in range(len(files_csv)):
    df_list.append(pd.read_csv(files_csv[i]))

# %%
for i in range(len(files_csv)):
    df_list[i] = df_list[i].iloc[:1000]
    df_list[i].to_csv(str(files_csv[i]))

# %%
df_list[1]
# Out:
#                              order_id                       customer_id  \
# 0    e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1    53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2    47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3    949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4    ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ..                                ...                               ...
# 995  e2493d49c7ac426207fb7575814ebbd4  660e0dca520294ab5ff435d0298627f9
# 996  be6e034d294e425c514e215bf0b7120a  ba7c84cd4d0db9d73b66a79e4d3e130c
# 997  777ee9a9950b655601a65012d4e45584  14e5f1e56b5d74d9fe35c39e8ba04699
# 998  f056d4857c146c38ff02566b3e152bca  fc6408fa8083f3c01b1f287709714321
# 999  8e3f8be6e1ce8ec5b39dae59e0aabcff  6520161e793f944073a132d97e9af083
#
#     order_status order_purchase_timestamp    order_approved_at  \
# ...
